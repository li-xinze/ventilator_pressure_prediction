# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# get into directory of project, for example: %cd /content/drive/MyDrive/Ventilator
# %cd /content/drive/MyDrive/Colab Notebooks/vent_tf/vent_tf
# Out:
# /content/drive/MyDrive/Colab Notebooks/vent_tf/vent_tf

# %%
# install packages
# !pip install --q livelossplot
# !pip install --q pytorch-lightning
# Out:
#      |████████████████████████████████| 1.0 MB 5.2 MB/s
#      |████████████████████████████████| 329 kB 20.9 MB/s
#      |████████████████████████████████| 829 kB 37.7 MB/s
#      |████████████████████████████████| 132 kB 47.2 MB/s
#      |████████████████████████████████| 596 kB 41.2 MB/s
#      |████████████████████████████████| 1.1 MB 39.8 MB/s
#      |████████████████████████████████| 192 kB 51.2 MB/s
#      |████████████████████████████████| 160 kB 55.2 MB/s
#      |████████████████████████████████| 271 kB 49.2 MB/s
# ...

# %%
# !pip install keras-tcn
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# ...

# %%
from main import jupyter_run

# %%
jupyter_run()
# Out:
# Created directory result/110_12/S_ALL/1
# Using config file: config/config.yaml
# Loading data...........
# Adding features..........
# Finish adding features
# Finish loading data!
# --------------- > Fold 1 < ---------------
# Created directory result/110_12/S_ALL/1/splits
# Epoch 1/200
# 52/52 [==============================] - ETA: 0s - loss: 5.8928
# Epoch 00001: val_loss improved from inf to 4.42438, saving model to result/110_12/S_ALL/1/models/folds0.hdf5
# 52/52 [==============================] - 58s 339ms/step - loss: 5.8928 - val_loss: 4.4244 - lr: 0.0010
# Epoch 2/200
# 52/52 [==============================] - ETA: 0s - loss: 3.4898
# Epoch 00002: val_loss improved from 4.42438 to 2.23935, saving model to result/110_12/S_ALL/1/models/folds0.hdf5
# 52/52 [==============================] - 12s 235ms/step - loss: 3.4898 - val_loss: 2.2393 - lr: 0.0010
# Epoch 3/200
# 52/52 [==============================] - ETA: 0s - loss: 1.9175
# ...
